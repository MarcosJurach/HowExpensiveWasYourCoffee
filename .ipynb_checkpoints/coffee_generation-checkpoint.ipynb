# %%
# Prediction of clients generation with the explicative features 
# ['customer_id','is_morning', 'sales_outlet_id', 'home_store', 'promo_yn', 'line_item_amount', 'weekday']

# %%
import os
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.compose import ColumnTransformer
from sklearn import preprocessing
from sklearn import utils
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor

import math as m
import scipy.stats as stats

# %%
os.chdir(r'C:\Users\alber\OneDrive\Desktop\IronHAck\DATASETS\mid_proyect')
data = pd.read_csv('coffee_refinal.csv')

# %%
#Remove duplicated in the DataFrame
data.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=False)
data.shape
data.head()
# Out:
#    product_id  customer_id  transaction_id transaction_date transaction_time  \
# 0          52          558               7       2019-04-01         12:04:43
# 1          27          781              11       2019-04-01         15:54:39
# 2          46          788              19       2019-04-01         14:34:59
# 3          23          683              32       2019-04-01         16:06:04
# 4          34           99              33       2019-04-01         19:18:37
#
#    sales_outlet_id  staff_id instore_yn  orders  line_item_id  ...  \
# 0                3        12          N       1             1  ...
# 1                3        17          N       1             1  ...
# 2                3        17          Y       1             1  ...
# 3                3        12          N       1             1  ...
# 4                3        17          Y       1             1  ...
#
#    current_retail_price  tax_exempt_yn  promo_yn new_product_yn  \
# 0                $2.50               Y         N              N
# 1                $3.50               Y         N              N
# 2                $2.50               Y         N              N
# 3                $2.50               Y         N              N
# 4                $2.45               Y         N              N
#
#    pa_sales_outlet_id pa_transaction_date start_of_day quantity_sold waste  \
# 0                 NaN                 NaN          NaN           NaN   NaN
# 1                 NaN                 NaN          NaN           NaN   NaN
# 2                 NaN                 NaN          NaN           NaN   NaN
# 3                 NaN                 NaN          NaN           NaN   NaN
# 4                 NaN                 NaN          NaN           NaN   NaN
#
#   perct_waste
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 39 columns]

# %%
data.home_store
# Out:
# 0         3.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         3.0
#          ...
# 280340    NaN
# 280341    8.0
# 280342    NaN
# 280343    8.0
# 280344    8.0
# Name: home_store, Length: 280345, dtype: float64

# %%
data.corr()
# Out:
#                          product_id  customer_id  transaction_id  \
# product_id                 1.000000     0.000269       -0.051162
# customer_id                0.000269     1.000000       -0.000943
# transaction_id            -0.051162    -0.000943        1.000000
# sales_outlet_id            0.016755     0.393914       -0.158806
# staff_id                   0.003236     0.262007       -0.056431
# orders                    -0.129846     0.000316       -0.063257
# line_item_id               0.618782     0.028388        0.098311
# quantity                  -0.446597     0.002954        0.023662
# line_item_amount          -0.274938     0.008788        0.021834
# unit_price                -0.060164    -0.014781       -0.029704
# home_store                 0.003059     0.954075       -0.043328
# birth_year                -0.003293     0.149841       -0.023217
# current_wholesame_price    0.258499    -0.010223       -0.046208
# pa_sales_outlet_id         0.012005    -0.000184       -0.000267
# start_of_day               0.387447     0.023906        0.043900
# quantity_sold              0.146801     0.008762        0.014030
# waste                      0.360786     0.021585        0.040273
# generation                -0.004217     0.152150       -0.029837
# is_morning                 0.047096    -0.028944       -0.354307
#
#                          sales_outlet_id  staff_id    orders  line_item_id  \
# product_id                      0.016755  0.003236 -0.129846      0.618782
# customer_id                     0.393914  0.262007  0.000316      0.028388
# transaction_id                 -0.158806 -0.056431 -0.063257      0.098311
# sales_outlet_id                 1.000000  0.666952  0.003537     -0.023427
# staff_id                        0.666952  1.000000  0.001424     -0.026941
# orders                          0.003537  0.001424  1.000000     -0.179243
# line_item_id                   -0.023427 -0.026941 -0.179243      1.000000
# quantity                       -0.017220 -0.017667 -0.032937     -0.479129
# line_item_amount                0.032057  0.022631  0.292458     -0.123599
# unit_price                     -0.002670  0.001259  0.512849      0.029592
# home_store                      1.000000  0.676362  0.001183      0.016818
# birth_year                      0.098395  0.064356  0.022338     -0.007908
# current_wholesame_price         0.005748  0.002205  0.415612      0.285954
# pa_sales_outlet_id             -0.000088 -0.000024  0.000387     -0.000537
# start_of_day                    0.022261  0.007361 -0.013606     -0.064489
# quantity_sold                   0.008748  0.002516 -0.003228     -0.036115
# waste                           0.019970  0.006657 -0.012516     -0.055068
# generation                      0.107019  0.074621  0.026748     -0.013892
# is_morning                      0.130933  0.013569  0.053247     -0.093401
#
#                          quantity  line_item_amount  unit_price  home_store  \
# product_id              -0.446597         -0.274938   -0.060164    0.003059
# customer_id              0.002954          0.008788   -0.014781    0.954075
# transaction_id           0.023662          0.021834   -0.029704   -0.043328
# sales_outlet_id         -0.017220          0.032057   -0.002670    1.000000
# staff_id                -0.017667          0.022631    0.001259    0.676362
# orders                  -0.032937          0.292458    0.512849    0.001183
# line_item_id            -0.479129         -0.123599    0.029592    0.016818
# quantity                 1.000000          0.387473   -0.124922   -0.019583
# line_item_amount         0.387473          1.000000    0.608013    0.032325
# unit_price              -0.124922          0.608013    1.000000   -0.001825
# home_store              -0.019583          0.032325   -0.001825    1.000000
# birth_year               0.013615          0.004554   -0.012738    0.098395
# current_wholesame_price -0.291841          0.426390    0.861761   -0.000450
# pa_sales_outlet_id      -0.001393          0.003140    0.011840    0.000133
# start_of_day             0.214489         -0.068571   -0.489828    0.018312
# quantity_sold            0.084159         -0.030711   -0.184055    0.006805
# waste                    0.191643         -0.057905   -0.433187    0.016854
# generation               0.007690          0.002783   -0.005224    0.107019
# is_morning              -0.025445         -0.033902    0.020917    0.131938
#
#                          birth_year  current_wholesame_price  \
# product_id                -0.003293                 0.258499
# customer_id                0.149841                -0.010223
# transaction_id            -0.023217                -0.046208
# sales_outlet_id            0.098395                 0.005748
# staff_id                   0.064356                 0.002205
# orders                     0.022338                 0.415612
# line_item_id              -0.007908                 0.285954
# quantity                   0.013615                -0.291841
# line_item_amount           0.004554                 0.426390
# unit_price                -0.012738                 0.861761
# home_store                 0.098395                -0.000450
# birth_year                 1.000000                -0.008719
# current_wholesame_price   -0.008719                 1.000000
# pa_sales_outlet_id        -0.000498                 0.008179
# start_of_day               0.010507                -0.599535
# quantity_sold              0.004048                -0.229329
# waste                      0.009169                -0.535840
# generation                 0.936000                -0.005747
# is_morning                 0.016909                 0.036141
#
#                          pa_sales_outlet_id  start_of_day  quantity_sold  \
# product_id                         0.012005      0.387447       0.146801
# customer_id                       -0.000184      0.023906       0.008762
# transaction_id                    -0.000267      0.043900       0.014030
# sales_outlet_id                   -0.000088      0.022261       0.008748
# staff_id                          -0.000024      0.007361       0.002516
# orders                             0.000387     -0.013606      -0.003228
# line_item_id                      -0.000537     -0.064489      -0.036115
# quantity                          -0.001393      0.214489       0.084159
# line_item_amount                   0.003140     -0.068571      -0.030711
# unit_price                         0.011840     -0.489828      -0.184055
# home_store                         0.000133      0.018312       0.006805
# birth_year                        -0.000498      0.010507       0.004048
# current_wholesame_price            0.008179     -0.599535      -0.229329
# pa_sales_outlet_id                 1.000000     -0.005922       0.121045
# start_of_day                      -0.005922      1.000000       0.392489
# quantity_sold                      0.121045      0.392489       1.000000
# waste                             -0.055728      0.893978      -0.046073
# generation                        -0.000095     -0.008469      -0.002958
# is_morning                         0.000439     -0.008642      -0.000081
#
#                             waste  generation  is_morning
# product_id               0.360786   -0.004217    0.047096
# customer_id              0.021585    0.152150   -0.028944
# transaction_id           0.040273   -0.029837   -0.354307
# sales_outlet_id          0.019970    0.107019    0.130933
# staff_id                 0.006657    0.074621    0.013569
# orders                  -0.012516    0.026748    0.053247
# line_item_id            -0.055068   -0.013892   -0.093401
# quantity                 0.191643    0.007690   -0.025445
# line_item_amount        -0.057905    0.002783   -0.033902
# unit_price              -0.433187   -0.005224    0.020917
# home_store               0.016854    0.107019    0.131938
# birth_year               0.009169    0.936000    0.016909
# current_wholesame_price -0.535840   -0.005747    0.036141
# pa_sales_outlet_id      -0.055728   -0.000095    0.000439
# start_of_day             0.893978   -0.008469   -0.008642
# quantity_sold           -0.046073   -0.002958   -0.000081
# waste                    1.000000   -0.007681   -0.008383
# generation              -0.007681    1.000000    0.022633
# is_morning              -0.008383    0.022633    1.000000

# %% [markdown]
# # Creating new columns

# %%
data.loc[(data.birth_year <= 1969), 'generation'] = 1
data.loc[(data.birth_year > 1969) & (data.birth_year < 1990 ) , 'generation'] = 2
data.loc[(data.birth_year >= 1990 ), 'generation'] = 3

# %%
data['is_morning']= (data["transaction_time"] >= '05:00:00') & (data["transaction_time"] <= '12:00:00')

# %%
data["transaction_date"] = data["transaction_date"].apply(pd.to_datetime)

data["weekday"] = data["transaction_date"].dt.strftime('%w')

# %w	Day of the week where Sunday=0 and Saturday=6

# %%
data.weekday.value_counts()
# Out:
# 1    45299
# 6    41872
# 0    39575
# 3    39155
# 4    38834
# 5    38526
# 2    37084
# Name: weekday, dtype: int64

# %%
data['is_morning'].value_counts()
# Out:
# True     166641
# False    113704
# Name: is_morning, dtype: int64

# %% [markdown]
# #### generation = 1 --> OLD
#
# #### generation = 2 --> ADULT
#
# #### generation = 3 --> YOUNG

# %%
data.columns
# Out:
# Index(['product_id', 'customer_id', 'transaction_id', 'transaction_date',
#        'transaction_time', 'sales_outlet_id', 'staff_id', 'instore_yn',
#        'orders', 'line_item_id', 'quantity', 'line_item_amount', 'unit_price',
#        'promo_item_yn', 'home_store', 'customer_first-name', 'customer_email',
#        'customer_since', 'loyalty_card_number', 'birthdate', 'gender',
#        'birth_year', 'product_group', 'product_category', 'product_type',
#        'product', 'product_description', 'unit_of_measure',
#        'current_wholesame_price', 'current_retail_price', 'tax_exempt_yn',
#        'promo_yn', 'new_product_yn', 'pa_sales_outlet_id',
#        'pa_transaction_date', 'start_of_day', 'quantity_sold', 'waste',
#        'perct_waste', 'generation', 'is_morning', 'weekday'],
#       dtype='object')

# %%
# Choosing features and dropping duplicates/NaNs. Maybe include 'instore_yn', 'product_group', 'new_product_yn', 'product_type'

X = data.loc[:, ['customer_id','is_morning', 'product_group',
             'home_store', 'generation', 'weekday', 'line_item_amount']]

X.drop_duplicates(keep='first', inplace=True, ignore_index=False)

X.dropna(inplace=True)


y = X.loc[:,'generation'] 
X = X.loc[:,['customer_id','is_morning', 'product_group',
             'home_store', 'line_item_amount', 'weekday']]

# %%
#Train/Test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

print("Nb rows X_train = {}".format(len(X_train)))
print("Nb rows X_test = {}".format(len(X_test)))
print("Nb rows y_train = {}".format(len(y_train)))
print("Nb rows y_test = {}".format(len(y_test)))
# Out:
# Nb rows X_train = 16713
# Nb rows X_test = 7163
# Nb rows y_train = 16713
# Nb rows y_test = 7163

# %%
y
# Out:
# 0         2.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         1.0
#          ...
# 280273    1.0
# 280339    1.0
# 280341    1.0
# 280343    3.0
# 280344    3.0
# Name: generation, Length: 23876, dtype: float64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23876 entries, 0 to 280344
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       23876 non-null  int64
#  1   is_morning        23876 non-null  bool
#  2   product_group     23876 non-null  object
#  3   home_store        23876 non-null  float64
#  4   line_item_amount  23876 non-null  float64
#  5   weekday           23876 non-null  int32
# dtypes: bool(1), float64(2), int32(1), int64(1), object(1)
# memory usage: 1.0+ MB

# %%
data['weekday'] = data['weekday'].astype(int)

# %%
# Encoding categorical features and standardizing numeric features

numeric_features = [0, 3, 4, 5] # Choose which column index we are going to scale
numeric_transformer = StandardScaler()

categorical_features = [1, 2] 
categorical_transformer = OneHotEncoder()


# Apply ColumnTransformer to create a pipeline that will apply the above preprocessing
feature_encoder = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features),    
        ('num', numeric_transformer, numeric_features)
        ]
    )


X_train = feature_encoder.fit_transform(X_train)
X_test = feature_encoder.transform(X_test)


#Encoding target variable
#encoder = LabelEncoder()
#y_train = encoder.fit_transform(y_train)
#y_test = encoder.transform(y_test)

# %%
model1 = LogisticRegression()
model2 = DecisionTreeRegressor()
model3 = RandomForestRegressor()

# %%
def Log_Reg(model):

    model.fit(X_train, y_train)
        
    # Evaluation of the model
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)
        
    print(classification_report(y_train, pred_train))
    print(classification_report(y_test, pred_test))
    
    # Visualize confusion matrices
    _ , ax = plt.subplots() # Get subplot from matplotlib
    ax.set(title="Confusion Matrix on Train set") # Set a title that we will add into ConfusionMatrixDisplay
    ConfusionMatrixDisplay.from_estimator(model, X_train, y_train, ax=ax) # ConfusionMatrixDisplay from sklearn
    plt.show()

    _ , ax = plt.subplots() # Get subplot from matplotlib
    ax.set(title="Confusion Matrix on Test set") # Set a title that we will add into ConfusionMatrixDisplay
    ConfusionMatrixDisplay.from_estimator(model, X_test, y_test, ax=ax)

# %%
def ran_for(model, forest):

    model.fit(X_train, y_train)
    
    # Evaluation of the model
    print("Train Score : {}".format(model.score(X_train, y_train)))
    print('Test Score : {}'.format(model.score(X_test, y_test)))

# %%
def dec_tree(model, leaf):
    
    model.fit(X_train, y_train)
    
    # Evaluation of the model
    print("Train Score : {}".format(model.score(X_train, y_train)))
    print('Test Score : {}'.format(model.score(X_test, y_test)))

# %%
Log_Reg(model1)
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.44      0.36      0.40      5351
#          2.0       0.42      0.56      0.48      6176
#          3.0       0.36      0.28      0.32      5186
#
#     accuracy                           0.41     16713
#    macro avg       0.41      0.40      0.40     16713
# weighted avg       0.41      0.41      0.40     16713
#
#               precision    recall  f1-score   support
#
#          1.0       0.45      0.36      0.40      2341
#          2.0       0.41      0.56      0.47      2609
#          3.0       0.37      0.28      0.32      2213
#
#     accuracy                           0.41      7163
#    macro avg       0.41      0.40      0.40      7163
# weighted avg       0.41      0.41      0.40      7163
